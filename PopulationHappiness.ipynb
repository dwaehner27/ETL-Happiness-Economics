# %%
#dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "Happiness_by_country_2020.csv"
happiness_df = pd.read_csv(csv_file)
happiness_df.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# ...

# %%
population = "Population_by_Country_2020.csv"
population_df = pd.read_csv(population)
population_df.head()
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                   China         1438207241         0.39%     5540090
# 1                   India         1377233523         0.99%    13586631
# 2           United States          330610570         0.59%     1937734
# 3               Indonesia          272931713         1.07%     2898047
# 4                Pakistan          219992900         2.00%     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              153          9388211       -348399.0        1.7       38
# 1              464          2973190       -532687.0        2.2       28
# 2               36          9147420        954806.0        1.8       38
# 3              151          1811570        -98955.0        2.3       30
# 4              287           770880       -233379.0        3.6       23
#
#   Urban Pop % World Share
# 0         61%      18.47%
# 1         35%      17.70%
# ...

# %%
refined_happiness_df = happiness_df[["Country name", "Regional indicator", "Ladder score", "Logged GDP per capita", "Social support", "Perceptions of corruption"]]
refined_happiness_df.head()
# Out:
#   Country name Regional indicator  Ladder score  Logged GDP per capita  \
# 0      Finland     Western Europe        7.8087              10.639267
# 1      Denmark     Western Europe        7.6456              10.774001
# 2  Switzerland     Western Europe        7.5599              10.979933
# 3      Iceland     Western Europe        7.5045              10.772559
# 4       Norway     Western Europe        7.4880              11.087804
#
#    Social support  Perceptions of corruption
# 0        0.954330                   0.195445
# 1        0.955991                   0.168489
# 2        0.942847                   0.303728
# 3        0.974670                   0.711710
# 4        0.952487                   0.263218

# %%
refined_population_df = population_df [["Country (or dependency)", "Population (2020)", "Density (P/Km²)", "Land Area (Km²)", "Migrants (net)", "Urban Pop %"]]
refined_population_df.head()
# Out:
#   Country (or dependency)  Population (2020)  Density (P/Km²)  \
# 0                   China         1438207241              153
# 1                   India         1377233523              464
# 2           United States          330610570               36
# 3               Indonesia          272931713              151
# 4                Pakistan          219992900              287
#
#    Land Area (Km²)  Migrants (net) Urban Pop %
# 0          9388211       -348399.0         61%
# 1          2973190       -532687.0         35%
# 2          9147420        954806.0         83%
# 3          1811570        -98955.0         56%
# 4           770880       -233379.0         35%

# %%
refined_happiness_df["Country name"].value_counts()
# Out:
# Morocco       1
# Lithuania     1
# Libya         1
# Belgium       1
# Bulgaria      1
#              ..
# Kyrgyzstan    1
# Sweden        1
# Botswana      1
# Nepal         1
# Mali          1
# Name: Country name, Length: 153, dtype: int64

# %%
refined_population_df["Country (or dependency)"].value_counts()
# Out:
# Curaçao       1
# Malawi        1
# Australia     1
# Nauru         1
# Uzbekistan    1
#              ..
# Moldova       1
# Panama        1
# Uganda        1
# Liberia       1
# Turkey        1
# Name: Country (or dependency), Length: 235, dtype: int64
